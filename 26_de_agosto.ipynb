# %%
import pandas as pd

# %% [markdown]
# # Lectura de datos

# %%
up = {"clases": ["fisica", "calculo", "POO"],
      "salones": 3,
      "profesor": ["oscar", "pablo"],
      "las_chidas": {"limon": 25,
                     "limon_preparado": 30,
                     "picante": 23.50}}
up
# Out:
# {'clases': ['fisica', 'calculo', 'POO'],
#  'salones': 3,
#  'profesor': ['oscar', 'pablo'],
#  'las_chidas': {'limon': 25, 'limon_preparado': 30, 'picante': 23.5}}

# %%
# Atributos de diccionario
up.keys()
# Out:
# dict_keys(['clases', 'salones', 'profesor', 'las_chidas'])

# %%
# Tranformar las llaves y valores usando funcion in-built lit
list(up.keys())
# Out:
# ['clases', 'salones', 'profesor', 'las_chidas']

# %%
up.values()
# Out:
# dict_values([['fisica', 'calculo', 'POO'], 3, ['oscar', 'pablo'], {'limon': 25, 'limon_preparado': 30, 'picante': 23.5}])

# %%
lista_up = list(up.values())
lista_up
# Out:
# [['fisica', 'calculo', 'POO'],
#  3,
#  ['oscar', 'pablo'],
#  {'limon': 25, 'limon_preparado': 30, 'picante': 23.5}]

# %%
# accesos
print(up["clases"])
print(lista_up[0])
# Out:
# ['fisica', 'calculo', 'POO']
# ['fisica', 'calculo', 'POO']

# %%
dicc = {"Isaac" : [2, "Bacardi", 7],
        "Max" : [3, "Tere", 21],
        "Marcos" : [6, "Alexa", 16],
        "Yoel" : [26, "Popo", 18]}

# %% [markdown]
# # DataFrames

# %%
df = pd.DataFrame(dicc)
df
# Out:
#      Isaac   Max Marcos  Yoel
# 0        2     3      6    26
# 1  Bacardi  Tere  Alexa  Popo
# 2        7    21     16    18

# %%
pd.read_csv("spotify-2023.csv", encoding="latin-1")
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# ## Lectura desde drive

# %%
# Instruccion para montar drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
spotify = pd.read_csv("/content/drive/MyDrive/POO–2024/spotify-2023.csv", encoding="latin-1")
spotify
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...
